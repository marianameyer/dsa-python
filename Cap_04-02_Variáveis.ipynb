# %% [markdown]
# #*Capítulo 4 - Variáveis*

# %%
# Verificando a versão do python
from platform import python_version
print(python_version())
# Out:
# 3.10.12

# %% [markdown]
# ##Trabalhando com Variáveis:

# %%
# Atribuindo valor 1 à variável var_teste
var_teste = 1

# %%
# Imprimindo o valor da variável
var_teste
# Out:
# 1

# %%
# Imprimindo o valor da variável
print(var_teste)
# Out:
# 1

# %%
# Não é possível usar uma variável que não foi definida. Veja a mensagem de erro
my_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6e9fe874f13d> in <cell line: 2>()
#       1 # Não é possível usar uma variável que não foi definida. Veja a mensagem de erro
# ----> 2 my_var
#
# NameError: name 'my_var' is not defined

# %%
var_teste = 2

# %%
var_teste
# Out:
# 2

# %%
type(var_teste)
# Out:
# int

# %%
var_teste = 9.5

# %%
type(var_teste)  # Tipificação dinâmica
# Out:
# float

# %%
x = 1

# %%
x
# Out:
# 1

# %% [markdown]
# ##Declaração Múltipla

# %%
pessoa1, pessoa2, pessoa3 = 'Bob', 'Maria', 'Ana'

# %%
pessoa1
# Out:
# 'Bob'

# %%
pessoa2
# Out:
# 'Maria'

# %%
pessoa3
# Out:
# 'Ana'

# %%
fruta1 = fruta2 = fruta3 = 'Melancia'

# %%
fruta1
# Out:
# 'Melancia'

# %%
fruta2
# Out:
# 'Melancia'

# %%
# Python é case sensitive
Fruta2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-677cc5e212fb> in <cell line: 2>()
#       1 # Python é case sensitive
# ----> 2 Fruta2
#
# NameError: name 'Fruta2' is not defined

# %%
x1 = 50

# %%
x1
# Out:
# 50

# %%
# Mensagem de erro: variáveis não podem ser iniciadas por números
1x
# Out:
#   File "<ipython-input-25-b994eeea9273>", line 1
#     1x
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Alguns nomes "proibidos":
#
#
# *   False;
# *   class;
# *   finally;
# *   return;
# *   None;
#
# dentre outros.

# %%
# Exemplo:
break = 1
# Out:
#   File "<ipython-input-26-3203c2f79a58>", line 2
#     break = 1
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##Variáveis Atribuídas a Outras Variáveis e Ordem dos Operadores

# %%
largura = 2

# %%
altura = 4

# %%
area = altura * largura

# %%
area
# Out:
# 8

# %%
perimetro = 2 * largura + 2 * altura

# %%
perimetro
# Out:
# 12

# %%
# A ordem dos operadores é a mesma seguida na matemática
perimetro = 2 * (largura + 2) * altura

# %%
perimetro
# Out:
# 32

# %% [markdown]
# ##Operações com Variáveis

# %%
idade1 = 25

# %%
idade2 = 35

# %%
idade1 + idade2
# Out:
# 60

# %%
idade2 - idade1
# Out:
# 10

# %%
idade2 * idade1
# Out:
# 875

# %%
idade2 / idade1
# Out:
# 1.4

# %%
idade2 % idade1
# Out:
# 10

# %% [markdown]
# ##Concatenação de Variáveis

# %%
nome = 'Bob'

# %%
sobrenome = 'Marley'

# %%
fullName = nome + ' ' + sobrenome

# %%
fullName
# Out:
# 'Bob Marley'

# %% [markdown]
# #FIM
