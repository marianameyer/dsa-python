# %% [markdown]
# #*Capítulo 4 - Dicionários*

# %% [markdown]
# ##Trabalhando com Dicionários

# %%
# Isso é uma lista
estudantes_lst = ['Pedro', 24, 'Ana', 22, 'Ronaldo', 26, 'Janaína', 25]

# %%
estudantes_lst
# Out:
# ['Pedro', 24, 'Ana', 22, 'Ronaldo', 26, 'Janaína', 25]

# %%
# Isso é um dicionário
estudantes_dict = {'Pedro':24, 'Ana':22, 'Ronaldo':26, 'Janaína':25}

# %%
estudantes_dict
# Out:
# {'Pedro': 24, 'Ana': 22, 'Ronaldo': 26, 'Janaína': 25}

# %%
estudantes_dict['Pedro']
# Out:
# 24

# %%
estudantes_dict['Marcelo'] = 23  # Adiciona o item (chave+valor) ao dicionário

# %%
estudantes_dict['Marcelo']
# Out:
# 23

# %%
estudantes_dict
# Out:
# {'Pedro': 24, 'Ana': 22, 'Ronaldo': 26, 'Janaína': 25, 'Marcelo': 23}

# %%
estudantes_dict.clear()

# %%
estudantes_dict
# Out:
# {}

# %%
del estudantes_dict

# %%
estudantes_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-29b87ec1321c> in <cell line: 1>()
# ----> 1 estudantes_dict
#
# NameError: name 'estudantes_dict' is not defined

# %%
estudantes = {'Pedro':24, 'Ana':22, 'Ronaldo':26, 'Janaína':25}

# %%
estudantes
# Out:
# {'Pedro': 24, 'Ana': 22, 'Ronaldo': 26, 'Janaína': 25}

# %%
type(estudantes)
# Out:
# dict

# %%
len(estudantes)
# Out:
# 4

# %%
estudantes.keys()  # Retorna as chaves
# Out:
# dict_keys(['Pedro', 'Ana', 'Ronaldo', 'Janaína'])

# %%
estudantes.values()  # Retorna os valores da chaves
# Out:
# dict_values([24, 22, 26, 25])

# %%
estudantes.items()
# Out:
# dict_items([('Pedro', 24), ('Ana', 22), ('Ronaldo', 26), ('Janaína', 25)])

# %%
estudantes2 = {'Camila':27, 'Adriana':28, 'Roberta':26}

# %%
estudantes2
# Out:
# {'Camila': 27, 'Adriana': 28, 'Roberta': 26}

# %%
estudantes.update(estudantes2)  # Adiciona ao final do dicionário

# %%
estudantes
# Out:
# {'Pedro': 24,
#  'Ana': 22,
#  'Ronaldo': 26,
#  'Janaína': 25,
#  'Camila': 27,
#  'Adriana': 28,
#  'Roberta': 26}

# %%
dict1 = {}

# %%
dict1
# Out:
# {}

# %%
dict1['chave_1'] = 2

# %%
print(dict1)
# Out:
# {'chave_1': 2}

# %%
dict1[10] = 5

# %%
dict1
# Out:
# {'chave_1': 2, 10: 5}

# %%
dict1[9.13] = 'Python'

# %%
dict1
# Out:
# {'chave_1': 2, 10: 5, 9.13: 'Python'}

# %%
dict1['teste'] = 5

# %%
dict1
# Out:
# {'chave_1': 2, 10: 5, 9.13: 'Python', 'teste': 5}

# %%
dict1 = {}

# %%
dict1
# Out:
# {}

# %%
dict1['teste'] = 10

# %%
dict1['key'] = 'teste'

# %%
# Atenção, pois chave e valor podem ser iguais, mas representam coisas diferentes
dict1
# Out:
# {'teste': 10, 'key': 'teste'}

# %%
dict2 = {}

# %%
dict2['key1'] = 'Data Science'

# %%
dict2['key2'] = 10

# %%
dict2['key3'] = 100

# %%
dict2
# Out:
# {'key1': 'Data Science', 'key2': 10, 'key3': 100}

# %%
a = dict2['key1']

# %%
b = dict2['key2']

# %%
c = dict2['key3']

# %%
a, b, c
# Out:
# ('Data Science', 10, 100)

# %%
# Dicionário de listas
dict3 = {'chave1':1230, 'chave2':[22,453,73.4], 'chave3':['picanha', 'fraldinha', 'alcatra']}

# %%
dict3
# Out:
# {'chave1': 1230,
#  'chave2': [22, 453, 73.4],
#  'chave3': ['picanha', 'fraldinha', 'alcatra']}

# %%
dict3['chave2']
# Out:
# [22, 453, 73.4]

# %%
# Acessando um item da lista, dentro do dicionário
dict3['chave3'][0].upper()  # Retorna o item na posição 0 da chave3 em CAPSLOCK
# Out:
# 'PICANHA'

# %%
# Operações com itens da lista, dentro do dicionário
var1 = dict3['chave2'][0] - 2

# %%
var1
# Out:
# 20

# %%
# Duas operações no mesmo comando, para atualizar um item dentro da lista
dict3['chave2'][0] -= 2

# %%
dict3
# Out:
# {'chave1': 1230,
#  'chave2': [20, 453, 73.4],
#  'chave3': ['picanha', 'fraldinha', 'alcatra']}

# %% [markdown]
# ##Criando Dicionários Aninhados

# %%
# Criando dicionários aninhados
dict_aninhado = {'key1':{'key2_aninhada':{'key3_aninhada':'Dict aninhado em Python'}}}

# %%
dict_aninhado
# Out:
# {'key1': {'key2_aninhada': {'key3_aninhada': 'Dict aninhado em Python'}}}

# %%
dict_aninhado['key1']['key2_aninhada']['key3_aninhada']
# Out:
# 'Dict aninhado em Python'
